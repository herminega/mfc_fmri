# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys, os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
sys.path.insert(0, PROJECT_ROOT)

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import OrderedDict
from statsmodels.stats.multitest import fdrcorrection, multipletests

from utils.config import FREQ_BANDS, ATLAS_PATH
from utils.io.io_atlas import load_atlas
from utils.io.io_results import load_fc_combined_data
from utils.analysis.functional_connectivity.fc_compute import bin_fcs_by_freq
from utils.analysis.functional_connectivity.fc_aggregate_network import aggregate_to_network_fc
from utils.analysis.functional_connectivity.fc_strength import compute_network_strength_df
from utils.analysis.functional_connectivity.fc_statistical_analysis import (
    networkpair_permtest,
    summarize_network_differences,
    compare_band_to_whole_network,
    compute_slow_network_drivers,
    get_network_edges,
    test_network_level,
    print_network_overview,
)
from utils.plot.plot_statistical_analysis import plot_network_edges

# --- Load combined FCs ---
RES_DIR = "/cluster/home/herminea/mental_health_project/workspace/results/fmri_prep/mvmd/combined_fc"

# %%
DIR = "/cluster/home/herminea/mental_health_project/workspace/results/fmri_prep/mvmd/imfs_new"
print("DIR contains number of files:", len(os.listdir(DIR)))
# Out:
# DIR contains number of files: 165

# %% [markdown]
# #### Prep for Statistical Analysis

# %%
### Load FC combined data
subjects_combined, fcs_by_imf, groups, freqs_by_imf = load_fc_combined_data(RES_DIR)

### Bin FCs by frequency bands
freq_bands_fc = {k: v for k, v in FREQ_BANDS.items() if k != "Whole"}
fcs_by_band = bin_fcs_by_freq(subjects_combined, freq_bands_fc)
fcs_by_band["Whole"] = {s: fcs_by_imf["whole"][s] for s in fcs_by_imf["whole"]}

order = ["Whole", "Slow-5", "Slow-4", "Slow-3", "Slow-2"]
fcs_by_band = OrderedDict((k, fcs_by_band[k]) for k in order if k in fcs_by_band)

### Aggregate FCs to network level
roi_to_net, n_networks, net_names_21 = load_atlas(ATLAS_PATH)
binned_netfcs = {
    band: {s: aggregate_to_network_fc(fc, roi_to_net, n_networks)
           for s, fc in subj_dict.items()}
    for band, subj_dict in fcs_by_band.items()
}

z_binned_netfcs = {}
for band, subj_fcs in binned_netfcs.items():
    z_binned_netfcs[band] = {}
    for s, fc in subj_fcs.items():
        fc_clipped = np.clip(fc, -0.999999, 0.999999)
        z_binned_netfcs[band][s] = np.arctanh(fc_clipped)  # Fisher z
# Out:
# [Load] Loaded 42 FC result files from /cluster/home/herminea/mental_health_project/workspace/results/fmri_prep/mvmd/combined_fc

# %% [markdown]
# # Statistical analysis

# %% [markdown]
# ### Permutation test

# %%
results_band = []
for band, subj_fcs in z_binned_netfcs.items():
    subs = list(subj_fcs.keys())
    group_labels = [groups[s] for s in subs]
    mdd = np.array([subj_fcs[s] for s, g in zip(subs, group_labels) if g == "MDD"])
    hc  = np.array([subj_fcs[s] for s, g in zip(subs, group_labels) if g == "HC"])

    diff_mat, p_mat, d_mat, g_mat = networkpair_permtest(mdd, hc)
    iu = np.triu_indices(n_networks, 1)
    df = pd.DataFrame({
        "Band": band,
        "Net1": [net_names_21[i] for i in iu[0]],
        "Net2": [net_names_21[j] for j in iu[1]],
        "ΔFC": diff_mat[iu],
        "p": p_mat[iu],
        "Cohen": d_mat[iu],
        "Hedges": g_mat[iu]
    })
    _, df["p_FDR"] = fdrcorrection(df["p"])
    results_band.append(df)

results_band = pd.concat(results_band)

summarize_network_differences(results_band, level_col="Band", top_n=5)
# Out:
# === Band Whole ===
#        DefaultA – LimbicB          ΔFC = -0.222, p = 0.0016, p_FDR = 0.1890 Cohen's d = -0.939, Hedges' g = -0.922, (↓ in MDD)
#         LimbicB – Cerebellum       ΔFC = -0.216, p = 0.0026, p_FDR = 0.1890 Cohen's d = -0.960, Hedges' g = -0.942, (↓ in MDD)
#         LimbicB – Thalamus         ΔFC = -0.124, p = 0.0040, p_FDR = 0.1890 Cohen's d = -0.879, Hedges' g = -0.862, (↓ in MDD)
#         LimbicB – SalVentAttnB     ΔFC = -0.211, p = 0.0044, p_FDR = 0.1890 Cohen's d = -0.886, Hedges' g = -0.870, (↓ in MDD)
#           ContB – LimbicB          ΔFC = -0.213, p = 0.0048, p_FDR = 0.1890 Cohen's d = -0.819, Hedges' g = -0.804, (↓ in MDD)
#
# === Band Slow-5 ===
#        Striatum – Cerebellum       ΔFC = -0.250, p = 0.0062, p_FDR = 0.4739 Cohen's d = -0.920, Hedges' g = -0.900, (↓ in MDD)
#         LimbicB – Thalamus         ΔFC = -0.168, p = 0.0102, p_FDR = 0.4739 Cohen's d = -0.906, Hedges' g = -0.886, (↓ in MDD)
#           ContB – Thalamus         ΔFC = -0.214, p = 0.0120, p_FDR = 0.4739 Cohen's d = -0.865, Hedges' g = -0.846, (↓ in MDD)
#        Thalamus – Cerebellum       ΔFC = -0.702, p = 0.0146, p_FDR = 0.4739 Cohen's d = -0.620, Hedges' g = -0.607, (↓ in MDD)
#         LimbicB – Cerebellum       ΔFC = -0.302, p = 0.0148, p_FDR = 0.4739 Cohen's d = -0.638, Hedges' g = -0.624, (↓ in MDD)
#
# === Band Slow-4 ===
#         LimbicB – Cerebellum       ΔFC = -0.226, p = 0.0018, p_FDR = 0.3779 Cohen's d = -0.984, Hedges' g = -0.966, (↓ in MDD)
#       DorsAttnB – Cerebellum       ΔFC = -0.357, p = 0.0150, p_FDR = 0.4031 Cohen's d = -0.694, Hedges' g = -0.681, (↓ in MDD)
#         LimbicB – Thalamus         ΔFC = -0.146, p = 0.0158, p_FDR = 0.4031 Cohen's d = -0.725, Hedges' g = -0.711, (↓ in MDD)
#           ContC – Cerebellum       ΔFC = -0.792, p = 0.0198, p_FDR = 0.4031 Cohen's d = -0.560, Hedges' g = -0.549, (↓ in MDD)
#       DorsAttnA – Cerebellum       ΔFC = -0.774, p = 0.0198, p_FDR = 0.4031 Cohen's d = -0.551, Hedges' g = -0.541, (↓ in MDD)
#
# === Band Slow-3 ===
#         LimbicB – Cerebellum       ΔFC = -0.102, p = 0.0080, p_FDR = 0.9994 Cohen's d = -0.858, Hedges' g = -0.841, (↓ in MDD)
#         LimbicB – Thalamus         ΔFC = -0.051, p = 0.1154, p_FDR = 0.9994 Cohen's d = -0.501, Hedges' g = -0.491, (↓ in MDD)
#         LimbicB – SomMotB          ΔFC = -0.058, p = 0.1548, p_FDR = 0.9994 Cohen's d = -0.452, Hedges' g = -0.444, (↓ in MDD)
#         SomMotA – Cerebellum       ΔFC = -0.075, p = 0.1572, p_FDR = 0.9994 Cohen's d = -0.441, Hedges' g = -0.432, (↓ in MDD)
#           ContB – LimbicB          ΔFC = -0.048, p = 0.1724, p_FDR = 0.9994 Cohen's d = -0.427, Hedges' g = -0.419, (↓ in MDD)
#
# === Band Slow-2 ===
#             MTL – Thalamus         ΔFC = +0.074, p = 0.0892, p_FDR = 0.9906 Cohen's d = 0.797, Hedges' g = 0.764, (↑ in MDD)
#         SomMotA – Cerebellum       ΔFC = -0.123, p = 0.0952, p_FDR = 0.9906 Cohen's d = -0.805, Hedges' g = -0.771, (↓ in MDD)
#           ContC – Thalamus         ΔFC = +0.049, p = 0.1204, p_FDR = 0.9906 Cohen's d = 0.725, Hedges' g = 0.695, (↑ in MDD)
#         LimbicB – Thalamus         ΔFC = -0.054, p = 0.1244, p_FDR = 0.9906 Cohen's d = -0.729, Hedges' g = -0.699, (↓ in MDD)
#         LimbicB – Cerebellum       ΔFC = -0.083, p = 0.1450, p_FDR = 0.9906 Cohen's d = -0.671, Hedges' g = -0.643, (↓ in MDD)

# %%
summary = []
for band, subj_fcs in z_binned_netfcs.items():
    subs = list(subj_fcs.keys())
    group_labels = [groups[s] for s in subs]
    mdd = np.array([subj_fcs[s] for s, g in zip(subs, group_labels) if g == "MDD"])
    hc  = np.array([subj_fcs[s] for s, g in zip(subs, group_labels) if g == "HC"])
    
    diff_mat = np.nanmean(mdd, axis=0) - np.nanmean(hc, axis=0)

    # Exclude self-connections
    diff_mat_no_diag = diff_mat.copy()
    np.fill_diagonal(diff_mat_no_diag, np.nan)

    mean_dfc = np.nanmean(diff_mat_no_diag, axis=1)
    
    df_band = pd.DataFrame({
        "Network": net_names_21,
        "ΔFC_mean": mean_dfc,
        "Band": band
    })
    summary.append(df_band)

summary_df = pd.concat(summary)

# plot per band
plt.figure(figsize=(10,5))
sns.barplot(data=summary_df, x="Network", y="ΔFC_mean", hue="Band")
plt.axhline(0, color='k', lw=1)
plt.xticks(rotation=90)
plt.title("Mean ΔFC per Network (MDD–HC)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Statistical analysis: Are slow bands more sensitive to group differences?

# %%
### Network level test
bands_to_test = ["Slow-5", "Slow-4", "Slow-3", "Slow-2"]
net_results = []
for b in bands_to_test:
    res = compare_band_to_whole_network(summary_df, band=b, n_perm=5000, random_state=42, alternative="greater")
    net_results.append(res)

# example: list of p-values from all tested bands
pvals = [res["p_perm"] for res in net_results]
bands = [res["band"] for res in net_results]

_, pvals_fdr = multipletests(pvals, method="fdr_bh")[:2]

for band, p, pfdr in zip(bands, pvals, pvals_fdr):
    # print results, p corrected
    print(f"{band:>7} p = {p:.4f},  p_FDR = {pfdr:.4f}, Cohen's d = {net_results[bands.index(band)]['cohen_d']:.4f}, Hedges' g = {net_results[bands.index(band)]['hedges_g']:.4f}")
# Out:
#  Slow-5 p = 0.0002,  p_FDR = 0.0008, Cohen's d = 1.5777, Hedges' g = 1.5146
#  Slow-4 p = 0.2697,  p_FDR = 0.5395, Cohen's d = 0.1359, Hedges' g = 0.1305
#  Slow-3 p = 1.0000,  p_FDR = 1.0000, Cohen's d = -2.4709, Hedges' g = -2.3721
#  Slow-2 p = 1.0000,  p_FDR = 1.0000, Cohen's d = -2.4928, Hedges' g = -2.3931

# %% [markdown]
# ### Network level analysis

# %%
strength = compute_network_strength_df(z_binned_netfcs, groups, net_names_21)
net_level_results = test_network_level(strength, n_perm=20000, seed=42)

# %%
print_network_overview(net_level_results)
# Out:
# ============================================================
# BAND: Slow-2
# ============================================================
# DefaultC        Δ=+0.028 | d=+0.356 | p=0.7837 | q=0.7837 | ↑ MDD
# ContC           Δ=+0.035 | d=+0.342 | p=0.7705 | q=0.7837 | ↑ MDD
# TempPar         Δ=+0.032 | d=+0.327 | p=0.7649 | q=0.7837 | ↑ MDD
# DorsAttnB       Δ=+0.035 | d=+0.295 | p=0.7352 | q=0.7837 | ↑ MDD
# LimbicB         Δ=-0.022 | d=-0.289 | p=0.2643 | q=0.7837 | ↓ MDD
# Cerebellum      Δ=-0.035 | d=-0.255 | p=0.2836 | q=0.7837 | ↓ MDD
# MTL             Δ=+0.018 | d=+0.250 | p=0.7040 | q=0.7837 | ↑ MDD
# Thalamus        Δ=+0.014 | d=+0.200 | p=0.6690 | q=0.7837 | ↑ MDD
# SomMotB         Δ=+0.018 | d=+0.168 | p=0.6426 | q=0.7837 | ↑ MDD
# SalVentAttnA    Δ=+0.019 | d=+0.167 | p=0.6401 | q=0.7837 | ↑ MDD
# DefaultA        Δ=+0.019 | d=+0.158 | p=0.6344 | q=0.7837 | ↑ MDD
# DorsAttnA       Δ=+0.014 | d=+0.150 | p=0.6263 | q=0.7837 | ↑ MDD
# DefaultB        Δ=+0.013 | d=+0.120 | p=0.6030 | q=0.7837 | ↑ MDD
# ContB           Δ=+0.014 | d=+0.118 | p=0.6029 | q=0.7837 | ↑ MDD
# ContA           Δ=+0.014 | d=+0.113 | p=0.5939 | q=0.7837 | ↑ MDD
# SomMotA         Δ=+0.013 | d=+0.097 | p=0.5866 | q=0.7837 | ↑ MDD
# VisCent         Δ=-0.004 | d=-0.055 | p=0.4451 | q=0.7837 | ↓ MDD
# LimbicA         Δ=-0.001 | d=-0.024 | p=0.4747 | q=0.7837 | ↓ MDD
# SalVentAttnB    Δ=+0.003 | d=+0.021 | p=0.5133 | q=0.7837 | ↑ MDD
# VisPeri         Δ=+0.001 | d=+0.013 | p=0.5059 | q=0.7837 | ↑ MDD
# Striatum        Δ=+0.000 | d=+0.007 | p=0.5008 | q=0.7837 | ↑ MDD
#
# ============================================================
# BAND: Slow-3
# ============================================================
# LimbicB         Δ=-0.039 | d=-0.399 | p=0.1005 | q=0.6618 | ↓ MDD
# SomMotA         Δ=-0.049 | d=-0.210 | p=0.2846 | q=0.6618 | ↓ MDD
# SomMotB         Δ=-0.033 | d=-0.177 | p=0.2942 | q=0.6618 | ↓ MDD
# MTL             Δ=+0.018 | d=+0.159 | p=0.6920 | q=0.6920 | ↑ MDD
# SalVentAttnA    Δ=-0.029 | d=-0.158 | p=0.3158 | q=0.6618 | ↓ MDD
# Cerebellum      Δ=-0.019 | d=-0.116 | p=0.3511 | q=0.6618 | ↓ MDD
# LimbicA         Δ=+0.011 | d=+0.108 | p=0.6303 | q=0.6618 | ↑ MDD
# VisCent         Δ=+0.014 | d=+0.106 | p=0.6297 | q=0.6618 | ↑ MDD
# DefaultC        Δ=+0.012 | d=+0.093 | p=0.6132 | q=0.6618 | ↑ MDD
# Striatum        Δ=-0.009 | d=-0.090 | p=0.3805 | q=0.6618 | ↓ MDD
# SalVentAttnB    Δ=-0.013 | d=-0.078 | p=0.3995 | q=0.6618 | ↓ MDD
# TempPar         Δ=+0.010 | d=+0.067 | p=0.5820 | q=0.6618 | ↑ MDD
# DorsAttnB       Δ=-0.008 | d=-0.045 | p=0.4395 | q=0.6618 | ↓ MDD
# Thalamus        Δ=-0.005 | d=-0.041 | p=0.4409 | q=0.6618 | ↓ MDD
# DorsAttnA       Δ=+0.006 | d=+0.041 | p=0.5491 | q=0.6618 | ↑ MDD
# DefaultB        Δ=+0.006 | d=+0.041 | p=0.5485 | q=0.6618 | ↑ MDD
# ContC           Δ=-0.004 | d=-0.033 | p=0.4526 | q=0.6618 | ↓ MDD
# VisPeri         Δ=+0.002 | d=+0.017 | p=0.5190 | q=0.6618 | ↑ MDD
# DefaultA        Δ=+0.002 | d=+0.010 | p=0.5069 | q=0.6618 | ↑ MDD
# ContB           Δ=-0.001 | d=-0.007 | p=0.4884 | q=0.6618 | ↓ MDD
# ContA           Δ=-0.001 | d=-0.006 | p=0.4880 | q=0.6618 | ↓ MDD
#
# ============================================================
# BAND: Slow-4
# ============================================================
# LimbicB         Δ=-0.123 | d=-0.609 | p=0.0253 | q=0.1212 | ↓ MDD *p<.05 (unc)*
# Cerebellum      Δ=-0.370 | d=-0.556 | p=0.0266 | q=0.1212 | ↓ MDD *p<.05 (unc)*
# SalVentAttnB    Δ=-0.373 | d=-0.504 | p=0.0395 | q=0.1212 | ↓ MDD *p<.05 (unc)*
# VisPeri         Δ=-0.308 | d=-0.498 | p=0.0547 | q=0.1212 | ↓ MDD
# VisCent         Δ=-0.157 | d=-0.492 | p=0.0589 | q=0.1212 | ↓ MDD
# DorsAttnA       Δ=-0.290 | d=-0.478 | p=0.0631 | q=0.1212 | ↓ MDD
# SalVentAttnA    Δ=-0.464 | d=-0.478 | p=0.0591 | q=0.1212 | ↓ MDD
# SomMotA         Δ=-0.387 | d=-0.474 | p=0.0756 | q=0.1212 | ↓ MDD
# ContB           Δ=-0.324 | d=-0.465 | p=0.0775 | q=0.1212 | ↓ MDD
# DorsAttnB       Δ=-0.365 | d=-0.457 | p=0.0933 | q=0.1212 | ↓ MDD
# SomMotB         Δ=-0.399 | d=-0.455 | p=0.0869 | q=0.1212 | ↓ MDD
# ContC           Δ=-0.342 | d=-0.454 | p=0.0593 | q=0.1212 | ↓ MDD
# ContA           Δ=-0.317 | d=-0.452 | p=0.0936 | q=0.1212 | ↓ MDD
# DefaultA        Δ=-0.333 | d=-0.444 | p=0.1039 | q=0.1212 | ↓ MDD
# Thalamus        Δ=-0.289 | d=-0.444 | p=0.0832 | q=0.1212 | ↓ MDD
# DefaultC        Δ=-0.311 | d=-0.442 | p=0.1000 | q=0.1212 | ↓ MDD
# Striatum        Δ=-0.068 | d=-0.428 | p=0.0872 | q=0.1212 | ↓ MDD
# DefaultB        Δ=-0.266 | d=-0.427 | p=0.1286 | q=0.1422 | ↓ MDD
# TempPar         Δ=-0.217 | d=-0.409 | p=0.0987 | q=0.1212 | ↓ MDD
# LimbicA         Δ=-0.067 | d=-0.327 | p=0.1689 | q=0.1773 | ↓ MDD
# MTL             Δ=-0.056 | d=-0.246 | p=0.2511 | q=0.2511 | ↓ MDD
#
# ============================================================
# BAND: Slow-5
# ============================================================
# Thalamus        Δ=-0.217 | d=-0.724 | p=0.0117 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# Cerebellum      Δ=-0.551 | d=-0.615 | p=0.0017 | q=0.0357 | ↓ MDD **FDR**
# VisCent         Δ=-0.427 | d=-0.532 | p=0.0320 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# Striatum        Δ=-0.077 | d=-0.527 | p=0.0626 | q=0.0692 | ↓ MDD
# VisPeri         Δ=-0.434 | d=-0.524 | p=0.0336 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# TempPar         Δ=-0.492 | d=-0.493 | p=0.0473 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# DorsAttnA       Δ=-0.517 | d=-0.475 | p=0.0271 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# ContC           Δ=-0.418 | d=-0.458 | p=0.0268 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# SomMotB         Δ=-0.471 | d=-0.455 | p=0.0848 | q=0.0890 | ↓ MDD
# SomMotA         Δ=-0.460 | d=-0.438 | p=0.0482 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# SalVentAttnA    Δ=-0.445 | d=-0.426 | p=0.0480 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# DefaultC        Δ=-0.445 | d=-0.421 | p=0.0507 | q=0.0622 | ↓ MDD
# SalVentAttnB    Δ=-0.431 | d=-0.419 | p=0.0219 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# LimbicB         Δ=-0.355 | d=-0.416 | p=0.0137 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# DefaultB        Δ=-0.348 | d=-0.404 | p=0.0431 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# ContB           Δ=-0.395 | d=-0.400 | p=0.0218 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# DorsAttnB       Δ=-0.404 | d=-0.394 | p=0.0533 | q=0.0622 | ↓ MDD
# DefaultA        Δ=-0.370 | d=-0.391 | p=0.0478 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# ContA           Δ=-0.380 | d=-0.371 | p=0.0524 | q=0.0622 | ↓ MDD
# LimbicA         Δ=-0.348 | d=-0.366 | p=0.0256 | q=0.0622 | ↓ MDD *p<.05 (unc)*
# MTL             Δ=-0.277 | d=-0.331 | p=0.1287 | q=0.1287 | ↓ MDD
#
# ============================================================
# BAND: Whole
# ============================================================
# LimbicB         Δ=-0.162 | d=-0.843 | p=0.0031 | q=0.0661 | ↓ MDD *p<.05 (unc)*
# VisCent         Δ=-0.222 | d=-0.610 | p=0.0264 | q=0.1060 | ↓ MDD *p<.05 (unc)*
# VisPeri         Δ=-0.291 | d=-0.583 | p=0.0205 | q=0.1060 | ↓ MDD *p<.05 (unc)*
# ContC           Δ=-0.241 | d=-0.568 | p=0.0230 | q=0.1060 | ↓ MDD *p<.05 (unc)*
# Thalamus        Δ=-0.118 | d=-0.549 | p=0.0344 | q=0.1060 | ↓ MDD *p<.05 (unc)*
# LimbicA         Δ=-0.127 | d=-0.496 | p=0.0356 | q=0.1060 | ↓ MDD *p<.05 (unc)*
# SalVentAttnB    Δ=-0.425 | d=-0.493 | p=0.0669 | q=0.1251 | ↓ MDD
# DorsAttnA       Δ=-0.355 | d=-0.488 | p=0.0651 | q=0.1251 | ↓ MDD
# TempPar         Δ=-0.296 | d=-0.473 | p=0.0454 | q=0.1060 | ↓ MDD *p<.05 (unc)*
# ContB           Δ=-0.337 | d=-0.458 | p=0.0821 | q=0.1251 | ↓ MDD
# DefaultA        Δ=-0.280 | d=-0.451 | p=0.0444 | q=0.1060 | ↓ MDD *p<.05 (unc)*
# DefaultB        Δ=-0.319 | d=-0.449 | p=0.0790 | q=0.1251 | ↓ MDD
# Striatum        Δ=-0.048 | d=-0.434 | p=0.0836 | q=0.1251 | ↓ MDD
# ContA           Δ=-0.352 | d=-0.427 | p=0.0893 | q=0.1251 | ↓ MDD
# DefaultC        Δ=-0.321 | d=-0.409 | p=0.0388 | q=0.1060 | ↓ MDD *p<.05 (unc)*
# SomMotA         Δ=-0.363 | d=-0.392 | p=0.1158 | q=0.1430 | ↓ MDD
# SalVentAttnA    Δ=-0.371 | d=-0.391 | p=0.1149 | q=0.1430 | ↓ MDD
# DorsAttnB       Δ=-0.355 | d=-0.361 | p=0.1323 | q=0.1463 | ↓ MDD
# MTL             Δ=-0.114 | d=-0.359 | p=0.1316 | q=0.1463 | ↓ MDD
# SomMotB         Δ=-0.273 | d=-0.349 | p=0.1411 | q=0.1482 | ↓ MDD
# Cerebellum      Δ=-0.242 | d=-0.302 | p=0.1914 | q=0.1914 | ↓ MDD

# %% [markdown]
# ### More analysis: Which specific networks contributed the most to that increase?

# %%
### Networks where Slow-5 adds the most group-difference signal compared to wholeband.
drivers_slow5 = compute_slow_network_drivers(summary_df, band_label="Slow-5")

# Look at top 10 networks driving the Slow-5 > Whole difference
print(drivers_slow5[["Network",
                     "ΔFC_mean_Whole",
                     "ΔFC_mean_Slow-5",
                     "abs_whole",
                     "abs_band",
                     "d_abs",
                     "dir_Whole",
                     "dir_Slow"]].head(21))
# Out:
#          Network  ΔFC_mean_Whole  ΔFC_mean_Slow-5  abs_whole  abs_band  \
# 0     Cerebellum       -0.242270        -0.551107   0.242270  0.551107
# 1        LimbicA       -0.127009        -0.348070   0.127009  0.348070
# 2        VisCent       -0.221633        -0.426834   0.221633  0.426834
# 3        SomMotB       -0.272589        -0.470633   0.272589  0.470633
# 4        TempPar       -0.295810        -0.491697   0.295810  0.491697
# 5        LimbicB       -0.162345        -0.355314   0.162345  0.355314
# 6          ContC       -0.241091        -0.418492   0.241091  0.418492
# 7            MTL       -0.113577        -0.277303   0.113577  0.277303
# 8      DorsAttnA       -0.354982        -0.516552   0.354982  0.516552
# 9        VisPeri       -0.291382        -0.434231   0.291382  0.434231
# 10      DefaultC       -0.321318        -0.444894   0.321318  0.444894
# 11      Thalamus       -0.118158        -0.216764   0.118158  0.216764
# 12       SomMotA       -0.362587        -0.459543   0.362587  0.459543
# 13      DefaultA       -0.279670        -0.369608   0.279670  0.369608
# 14  SalVentAttnA       -0.371045        -0.444998   0.371045  0.444998
# 15         ContB       -0.336706        -0.394746   0.336706  0.394746
# 16     DorsAttnB       -0.355112        -0.404270   0.355112  0.404270
# 17      Striatum       -0.048135        -0.077199   0.048135  0.077199
# 18      DefaultB       -0.319289        -0.348260   0.319289  0.348260
# 19         ContA       -0.352005        -0.380076   0.352005  0.380076
# 20  SalVentAttnB       -0.424976        -0.430690   0.424976  0.430690
#
#        d_abs dir_Whole  dir_Slow
# 0   0.308836  MDD < HC  MDD < HC
# 1   0.221061  MDD < HC  MDD < HC
# 2   0.205201  MDD < HC  MDD < HC
# 3   0.198044  MDD < HC  MDD < HC
# 4   0.195887  MDD < HC  MDD < HC
# 5   0.192970  MDD < HC  MDD < HC
# 6   0.177401  MDD < HC  MDD < HC
# 7   0.163725  MDD < HC  MDD < HC
# 8   0.161570  MDD < HC  MDD < HC
# 9   0.142849  MDD < HC  MDD < HC
# 10  0.123576  MDD < HC  MDD < HC
# 11  0.098606  MDD < HC  MDD < HC
# 12  0.096957  MDD < HC  MDD < HC
# 13  0.089938  MDD < HC  MDD < HC
# 14  0.073953  MDD < HC  MDD < HC
# 15  0.058041  MDD < HC  MDD < HC
# 16  0.049158  MDD < HC  MDD < HC
# 17  0.029063  MDD < HC  MDD < HC
# 18  0.028971  MDD < HC  MDD < HC
# 19  0.028071  MDD < HC  MDD < HC
# 20  0.005713  MDD < HC  MDD < HC

# %%
seed = "LimbicA"
band = "Slow-5"
limbica_slow_edges = get_network_edges(results_band, seed_network=seed, band_label=band)

print(limbica_slow_edges)
plot_network_edges(limbica_slow_edges, seed_network=seed, band_label=band)
# Out:
#       Connection       ΔFC    Band
# 0     Cerebellum -0.482647  Slow-5
# 1        TempPar -0.427628  Slow-5
# 2       DefaultA -0.417798  Slow-5
# 3        SomMotB -0.416112  Slow-5
# 4          ContB -0.407022  Slow-5
# 5       DefaultB -0.406174  Slow-5
# 6   SalVentAttnB -0.404262  Slow-5
# 7        LimbicB -0.402043  Slow-5
# 8          ContC -0.400855  Slow-5
# 9       DefaultC -0.395194  Slow-5
# 10           MTL -0.395125  Slow-5
# 11       SomMotA -0.394358  Slow-5
# 12  SalVentAttnA -0.392630  Slow-5
# 13     DorsAttnA -0.390696  Slow-5
# 14         ContA -0.375022  Slow-5
# 15     DorsAttnB -0.357867  Slow-5
# 16       VisPeri -0.156873  Slow-5
# 17       VisCent -0.149373  Slow-5
# 18      Thalamus -0.125422  Slow-5
# 19      Striatum -0.064304  Slow-5
